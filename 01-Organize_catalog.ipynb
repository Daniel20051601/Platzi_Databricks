-- %%
CREATE CATALOG IF NOT EXISTS platzi
COMMENT "Catalog para elk curso de Platzi de Databricks";

-- %%
USE CATALOG platzi;
CREATE SCHEMA IF NOT EXISTS customers;

-- %%
USE CATALOG platzi;
USE SCHEMA customers;
CREATE VOLUME IF NOT EXISTS example_data
COMMENT "Archivos de ejemplo para las practicas del curso"
